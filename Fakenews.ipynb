# %%
import pandas as pd
import numpy as np

# %%
true = pd.read_csv("sample_data/True.csv")

# %%
fake = pd.read_csv("sample_data/Fake.csv")

# %%
true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
true['label'] = 1
fake['label'] = 0

# %%
true.head(10)
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
# 5  White House, Congress prepare for talks on spe...
# 6  Trump says Russia probe will be fair, but time...
# 7  Factbox: Trump on Twitter (Dec 29) - Approval ...
# 8         Trump on Twitter (Dec 28) - Global Warming
# 9  Alabama official to certify Senator-elect Jone...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
# 5  WEST PALM BEACH, Fla./WASHINGTON (Reuters) - T...  politicsNews
# 6  WEST PALM BEACH, Fla (Reuters) - President Don...  politicsNews
# 7  The following statements were posted to the ve...  politicsNews
# 8  The following statements were posted to the ve...  politicsNews
# 9  WASHINGTON (Reuters) - Alabama Secretary of St...  politicsNews
#
#                  date  label
# 0  December 31, 2017       1
# 1  December 29, 2017       1
# 2  December 31, 2017       1
# 3  December 30, 2017       1
# 4  December 29, 2017       1
# 5  December 29, 2017       1
# 6  December 29, 2017       1
# 7  December 29, 2017       1
# 8  December 29, 2017       1
# 9  December 28, 2017       1

# %%
news = pd.concat([fake, true],axis=0)

# %%
news.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date  label
# 0  December 31, 2017      0
# 1  December 31, 2017      0
# 2  December 30, 2017      0
# 3  December 29, 2017      0
# 4  December 25, 2017      0

# %%
news.tail()
# Out:
#                                                    title  \
# 21412  'Fully committed' NATO backs new U.S. approach...
# 21413  LexisNexis withdrew two products from Chinese ...
# 21414  Minsk cultural hub becomes haven from authorities
# 21415  Vatican upbeat on possibility of Pope Francis ...
# 21416  Indonesia to buy $1.14 billion worth of Russia...
#
#                                                     text    subject  \
# 21412  BRUSSELS (Reuters) - NATO allies on Tuesday we...  worldnews
# 21413  LONDON (Reuters) - LexisNexis, a provider of l...  worldnews
# 21414  MINSK (Reuters) - In the shadow of disused Sov...  worldnews
# 21415  MOSCOW (Reuters) - Vatican Secretary of State ...  worldnews
# 21416  JAKARTA (Reuters) - Indonesia will buy 11 Sukh...  worldnews
#
#                    date  label
# 21412  August 22, 2017       1
# 21413  August 22, 2017       1
# 21414  August 22, 2017       1
# 21415  August 22, 2017       1
# 21416  August 22, 2017       1

# %%
news.isnull().sum()
# Out:
# title      0
# text       0
# subject    0
# date       0
# label      0
# dtype: int64

# %%
news = news.drop(['title','subject','date'],axis=1)

# %%
news.head()
# Out:
#                                                 text  label
# 0  Donald Trump just couldn t wish all Americans ...      0
# 1  House Intelligence Committee Chairman Devin Nu...      0
# 2  On Friday, it was revealed that former Milwauk...      0
# 3  On Christmas day, Donald Trump announced that ...      0
# 4  Pope Francis used his annual Christmas Day mes...      0

# %%
news = news.sample(frac=1)               #Reshuffling

# %%
news.head()
# Out:
#                                                     text  label
# 22192  21st Century Wire says Yesterday, President Do...      0
# 2126   It appears that a hacker had a bit of fun with...      0
# 10903  So much for healthy debate on college campus I...      0
# 12609  Here s Wikipedia on Dominion Voting: Yes, they...      0
# 9284    I think this is hope over reality longtime De...      0

# %%
news.reset_index(inplace=True)

# %%
news.head()
# Out:
#    index                                               text  label
# 0  22192  21st Century Wire says Yesterday, President Do...      0
# 1   2126  It appears that a hacker had a bit of fun with...      0
# 2  10903  So much for healthy debate on college campus I...      0
# 3  12609  Here s Wikipedia on Dominion Voting: Yes, they...      0
# 4   9284   I think this is hope over reality longtime De...      0

# %%
news.drop(['index'],axis=1, inplace = True)

# %%
news.head()
# Out:
#                                                 text  label
# 0  21st Century Wire says Yesterday, President Do...      0
# 1  It appears that a hacker had a bit of fun with...      0
# 2  So much for healthy debate on college campus I...      0
# 3  Here s Wikipedia on Dominion Voting: Yes, they...      0
# 4   I think this is hope over reality longtime De...      0

# %%
import re

# %%
def wordopt(text):
    #convert into lowercase
    text = text.lower()

    #Remove URLs 
    text = re.sub(r'https?://\S+|www\.\S+','',text)

    #Remove HTML tags
    text = re.sub(r'<.*?>', '',text)

    #Remove punctuation
    text = re.sub(r'[^\w\s]', '', text)

    #Remove digits
    text = re.sub(r'\d', '', text)

    #Remove newline characters
    text = re.sub(r'\n', ' ', text)

    return text

# %%
news['text'] = news['text'].apply(wordopt)

# %%
news['text']
# Out:
# 0        st century wire says yesterday president donal...
# 1        it appears that a hacker had a bit of fun with...
# 2        so much for healthy debate on college campus i...
# 3        here s wikipedia on dominion voting yes they c...
# 4         i think this is hope over reality longtime de...
#                                ...
# 44893    if you ve been privy to any form of a donald t...
# 44894    donald trump has been on an absolute tear on t...
# 44895    rome reuters  rescuers pulled  boat migrants t...
# 44896    brussels reuters  european council president d...
# 44897    reuters  the us labor department on friday def...
# Name: text, Length: 44898, dtype: object

# %%
x
# Out:
# 0        reuters  republican us presidentelect donald t...
# 1        washington reuters  us president donald trump ...
# 2        comedian dave chappelle has been prepping for ...
# 3        kiev reuters  spanish foreign minister alfonso...
# 4        the president who shoved his radical agenda do...
#                                ...
# 44893    washington reuters  us president donald trump ...
# 44894    donald trump has been notorious for touting po...
# 44895    the good news for hillary is that she should b...
# 44896    washington reuters  donald trumps decision to ...
# 44897    berlin reuters  a german court sentenced a yea...
# Name: text, Length: 44898, dtype: object

# %%
x = news['text']
y = news['label']

# %%
y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 44893    0
# 44894    0
# 44895    1
# 44896    1
# 44897    1
# Name: label, Length: 44898, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3)

# %%
x_train.shape
# Out:
# (31428,)

# %%
x_test.shape
# Out:
# (13470,)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorization = TfidfVectorizer()

# %%
xv_train = vectorization.fit_transform(x_train)

# %%
xv_test = vectorization.transform(x_test)

# %%
xv_train
# Out:
# <31428x174590 sparse matrix of type '<class 'numpy.float64'>'
# 	with 6442992 stored elements in Compressed Sparse Row format>

# %%
xv_test
# Out:
# <13470x174590 sparse matrix of type '<class 'numpy.float64'>'
# 	with 2737418 stored elements in Compressed Sparse Row format>

# %%
from sklearn.linear_model import LogisticRegression

# %%
LR = LogisticRegression()

# %%
LR.fit(xv_train, y_train)
# Out:
# LogisticRegression()

# %%
pred_lr = LR.predict(xv_test)

# %%
LR.score(xv_test, y_test)
# Out:
# 0.987750556792873

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test, pred_lr))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      7114
#            1       0.99      0.99      0.99      6356
#
#     accuracy                           0.99     13470
#    macro avg       0.99      0.99      0.99     13470
# weighted avg       0.99      0.99      0.99     13470

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
DTC = DecisionTreeClassifier()

# %%
DTC.fit(xv_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred_dtc = DTC.predict(xv_test)

# %%
DTC.score(xv_test, y_test)
# Out:
# 0.9956198960653304

# %%
print(classification_report(y_test, pred_dtc))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7114
#            1       0.99      1.00      1.00      6356
#
#     accuracy                           1.00     13470
#    macro avg       1.00      1.00      1.00     13470
# weighted avg       1.00      1.00      1.00     13470

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier()

# %%
rfc.fit(xv_train, y_train)
# Out:
# RandomForestClassifier()

# %%
predict_rfc = rfc.predict(xv_test)

# %%
rfc.score(xv_test, y_test)
# Out:
# 0.9872308834446919

# %%
print(classification_report(y_test,predict_rfc))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      7114
#            1       0.99      0.99      0.99      6356
#
#     accuracy                           0.99     13470
#    macro avg       0.99      0.99      0.99     13470
# weighted avg       0.99      0.99      0.99     13470

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
gbc = GradientBoostingClassifier()

# %%
gbc.fit(xv_train, y_train)
# Out:
# GradientBoostingClassifier()

# %%
pred_gbc = gbc.predict(xv_test)

# %%
gbc.score(xv_test, y_test)
# Out:
# 0.9956198960653304

# %%
print(classification_report(y_test, pred_gbc))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00      7114
#            1       0.99      1.00      1.00      6356
#
#     accuracy                           1.00     13470
#    macro avg       1.00      1.00      1.00     13470
# weighted avg       1.00      1.00      1.00     13470

# %%
def output_label(n):
    if n==0:
        return "It is a Fake News"
    elif n==1:
        return "It is a Genuine News"

# %%
def manual_testing(news):
    testing_news = {"text": [news]}
    new_def_test = pd.DataFrame(testing_news)
    new_def_test["text"] = new_def_test["text"].apply(wordopt)
    new_x_test = new_def_test["text"]
    new_xv_test = vectorization.transform(new_x_test)
    pred_lr = LR.predict(new_xv_test)
    pred_gbc = gbc.predict(new_xv_test)
    pred_rfc = rfc.predict(new_xv_test)
    return "\n\nLR Prediction: {} \nGBC Prediction: {} \nRFC Prediction: {}".format(
        output_label(pred_lr[0]), output_label(pred_gbc[0]), output_label(pred_rfc[0]))

# %%
news_article = str(input())
# Out:
#  WASHINGTON (Reuters) - As a budget deadline approaches, Republicans in the U.S. Congress are reconsidering their fiscal strategy, according to party officials. Lawmakers said internal disagreements could complicate negotiations in the coming weeks.

# %%
manual_testing(news_article)
# Out:
# '\n\nLR Prediction: It is a Genuine News \nGBC Prediction: It is a Genuine News \nRFC Prediction: It is a Genuine News'
